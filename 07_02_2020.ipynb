# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0518/python-basics/blob/master/07_02_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt 
df=pd.read_csv("tableconvert_2020-02-29_113532.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X=df[["petal_length","petal_width"]].values
y=df["sepal_length"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
model = LinearRegression()  
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# 4.186361938764403

# %%
model.coef_
# Out:
# array([ 0.53528433, -0.29264758])

# %%
predicted_quality=model.predict(X_test)
predicted_quality.shape
# Out:
# (38,)

# %%
Actual_predicted=pd.DataFrame({"Actual": y_test.flatten(), "Predicted": predicted_quality.flatten()})
Actual_predicted.head()
# Out:
#    Actual  Predicted
# 0     6.5   6.647186
# 1     6.0   6.228961
# 2     7.0   6.292492
# 3     6.8   6.515866
# 4     5.0   5.767210

# %%
dd=pd.read_csv("students_placement_data.csv")
dd
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
ds=dd.loc[dd['Section']=='A']
ds
# Out:
#     Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0         1      M  ...                                 NO        Not placed
# 1         2      F  ...                                yes            Placed
# 2         3      F  ...                                yes        Not placed
# 3         4      M  ...                                yes        Not placed
# 4         5      M  ...                                yes        Not placed
# 5         6      M  ...                                yes        Not placed
# 6         7      M  ...                                yes        Not placed
# 7         8      F  ...                                 NO        Not placed
# 8         9      M  ...                                yes        Not placed
# 9        10      M  ...                                yes        Not placed
# 10       11      F  ...                                 NO            Placed
# ...

# %%
dk=dd.loc[dd["Section"]=="B"]
dk
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 60        61      F  ...                                 NO        Not placed
# 61        62      F  ...                                 NO            Placed
# 62        63      M  ...                                 NO        Not placed
# 63        64      M  ...                                yes        Not placed
# 64        65      F  ...                                 NO            Placed
# 65        66      F  ...                                yes            Placed
# 66        67      F  ...                                yes            Placed
# 67        68      F  ...                                yes            Placed
# 68        69      M  ...                                 NO        Not placed
# 69        70      M  ...                                 NO        Not placed
# 70        71      F  ...                                yes            Placed
# ...

# %%
ds.boxplot()

# %%
dk.boxplot()
